# %%
# Deskriptive Statistik
# mit Pandas und via_intermediary = 0

import operator
from dateutil import parser
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import re
import json
import pandas as pd
from matplotlib_venn import venn2, venn3
import matplotlib.cm as cm

# %%
# Synonyme für PFP als Liste
pfp_gen = ['Pflegefachperson', 'Pflegefachfrau', 'Pflegefachmann', 'Pflegefachkraft']
pfp_kh =  ['Krankenschwester', 'Krankenpfleger', 'Krankenpflegefachperson']
pfp_ap = ['Altenpfleger', 'Altenpflegefachkraft', 'Altenpflegefachperson']
pfp_ki = ['Kinderkrankenschwester', 'Kinderkrankenpfleger', 'Kinderkrankenpflegefachperson'] 
# Die Bezeichnungen in pfp_ki entsprechen den Bezeichnungen in pfp_kh mit dem Zusatz "Kinder".
# Falls in pfp_ki eine Bezeichnung steht, die dieser Regel widerspricht, so wird diese nicht gezählt!!
# Außerdem muss pfp_ki[n] auch pfp_kh[n] entsprechen (jeweils mit/ohne Kinder-), sonst funktioniert der Zähler nicht (Z. 142f.)!
# Dieser Regel darf also nicht widersprochen werden!
# Weibliche Formen, die nur durch -in entstehen, werden nicht beachtet bzw. zählen zu den männlichen dazu

# %%
# Echte Daten
years = ['2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'] # Hier die Jahre angeben, die geladen werden sollen (final: 2016-2023)
path = "/Users/jan/Documents/Promotion/BIBB GW/hdd/Pflege/"#Hier der Pfad zu den JSON-Dateien!
count_gen_oza = {}
count_kh_oza = {}
count_ki_oza = {}
count_ap_oza = {}
count_all_oza = {}
count_kh_gen = {}
count_kh_ki = {}
count_kh_ap = {}
count_gen_ki = {}
count_gen_ap = {}
count_ki_ap = {}
count_kh_gen_ki = {}
count_kh_gen_ap = {}
count_kh_ki_ap = {}
count_gen_ki_ap = {}
count_gen_ki_ap_kh = {}
count_vars_unique = {}
count_einser = {}
count_zweier = {}
count_dreier = {}
total_count = {}
total_nan = {}
fehler = {}
month_counts = {}  # Speichert die Anzahl der Stellenanzeigen für jedes (Jahr, Monat)
all_months = set()
year_counts = {}  # Speichert die Anzahl der Stellenanzeigen für jedes Jahr
all_years = set()
count_all_gen = {}
count_all_kh = {}
count_all_ki = {}
count_all_ap = {}
for year in years:
    # Hier Jahr öffnen (json), filtern, Variablen rausholen, löschen
    with open(f"{path}Pflege_{year}.json", 'r') as file:
        output = json.load(file)
    sorted_indices = sorted(output["date"], key=lambda i: output["date"][i])
    #df_full = pd.DataFrame(sorted_indices)
    df_full = pd.DataFrame({
        "date": [output["date"][i] for i in sorted_indices],
        "full_text": [output["full_text"][i] for i in sorted_indices],
        "via_intermediary": [output["via_intermediary"][i] for i in sorted_indices],
        "contract_type": [output["contract_type"][i] for i in sorted_indices]
    })
    del sorted_indices
    # Intermediarys rausfiltern
    df_full = df_full[df_full["via_intermediary"] != True]
    df_full['gen'] = pd.NA
    df_full['kh'] = pd.NA
    df_full['ki'] = pd.NA
    df_full['ap'] = pd.NA
    for i in range(len(pfp_gen)):
        result = df_full['full_text'].str.contains(pfp_gen[i], case=False, na=False)
        df_full.loc[result, 'gen'] = 1
    for i in range(len(pfp_kh)):
        result = df_full['full_text'].str.contains(rf'\b{pfp_kh[i]}', case=False, na=False)
        df_full.loc[result, 'kh'] = 1
    for i in range(len(pfp_ki)):
        result = df_full['full_text'].str.contains(pfp_ki[i], case=False, na=False)
        df_full.loc[result, 'ki'] = 1
    for i in range(len(pfp_ap)):
        result = df_full['full_text'].str.contains(pfp_ap[i], case=False, na=False)
        df_full.loc[result, 'ap'] = 1
    fehler[year] = (df_full['ki'].isna() & df_full['gen'].isna() & df_full['kh'].isna() & df_full['ap'].isna()).sum()
    print(f"NaN-Fehler in Jahr {year}: {fehler[year]}")
    count_gen_oza[year] = (df_full['gen'] == 1 & df_full['ap'].isna() & df_full['kh'].isna() & df_full['ki'].isna()).sum()
    count_kh_oza[year] = (df_full['kh'] == 1 & df_full['ap'].isna() & df_full['ki'].isna() & df_full['gen'].isna()).sum()
    count_ki_oza[year] = (df_full['ki'] == 1 & df_full['ap'].isna() & df_full['gen'].isna() & df_full['kh'].isna()).sum()
    count_ap_oza[year] = (df_full['ap'] == 1 & df_full['ki'].isna() & df_full['gen'].isna() & df_full['kh'].isna()).sum()
    count_all_oza[year] = len(df_full)
    count_all_gen[year] = (df_full['gen'] == 1).sum()
    count_all_kh[year] = (df_full['kh'] == 1).sum()
    count_all_ki[year] = (df_full['ki'] == 1).sum()
    count_all_ap[year] = (df_full['ap'] == 1).sum()
    print(f"Stellenanzeigen in {year} insgesamt: {count_all_oza[year]}")
    print(f"Stellenanzeigen in {year} nur mit generalistischen Berufsbezeichnungen: {count_gen_oza[year]}")
    print(f"Stellenanzeigen in {year} nur mit Berufsbezeichnungen der Akutpflege: {count_kh_oza[year]}")
    print(f"Stellenanzeigen in {year} nur mit Berufsbezeichnungen der Kinderkrankenpflege: {count_ki_oza[year]}")
    print(f"Stellenanzeigen in {year} nur mit Berufsbezeichnungen der Altenpflege: {count_ap_oza[year]}")
    print("\nJetzt filtern:")
    # Kombination von 'kh' und 'gen'
    count_kh_gen[year] = ((df_full['kh'] == 1) & (df_full['gen'] == 1) & df_full['ki'].isna() & df_full['ap'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit kh = 1 und gen = 1: {count_kh_gen[year]}")
    # Kombination von 'kh' und 'ki'
    count_kh_ki[year] = ((df_full['kh'] == 1) & (df_full['ki'] == 1) & df_full['gen'].isna() & df_full['ap'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit kh = 1 und ki = 1: {count_kh_ki[year]}")
    # Kombination von 'kh' und 'ap'
    count_kh_ap[year] = ((df_full['kh'] == 1) & (df_full['ap'] == 1) & df_full['ki'].isna() & df_full['gen'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit kh = 1 und ap = 1: {count_kh_ap[year]}")
    # Kombination von 'gen' und 'ki'
    count_gen_ki[year] = ((df_full['gen'] == 1) & (df_full['ki'] == 1) & df_full['kh'].isna() & df_full['ap'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit gen = 1 und ki = 1: {count_gen_ki[year]}")
    # Kombination von 'gen' und 'ap'
    count_gen_ap[year] = ((df_full['gen'] == 1) & (df_full['ap'] == 1) & df_full['ki'].isna() & df_full['kh'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit gen = 1 und ap = 1: {count_gen_ap[year]}")
    # Kombination von 'ki' und 'ap'
    count_ki_ap[year] = ((df_full['ki'] == 1) & (df_full['ap'] == 1) & df_full['gen'].isna() & df_full['kh'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit ki = 1 und ap = 1: {count_ki_ap[year]}")
    # Kombination von 'kh', 'gen' und 'ki'
    count_kh_gen_ki[year] = ((df_full['kh'] == 1) & (df_full['ki'] == 1) & (df_full['gen'] == 1) & df_full['ap'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit kh = 1, gen = 1 und ki = 1: {count_kh_gen_ki[year]}")
    # Kombination von 'kh', 'gen' und 'ap'
    count_kh_gen_ap[year] = ((df_full['kh'] == 1) & (df_full['gen'] == 1) & (df_full['ap'] == 1) & df_full['ki'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit kh = 1, gen = 1 und ap = 1: {count_kh_gen_ap[year]}")
    # Kombination von 'kh', 'ki' und 'ap'
    count_kh_ki_ap[year] = ((df_full['kh'] == 1) & (df_full['ki'] == 1) & (df_full['ap'] == 1) & df_full['gen'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit kh = 1, ki = 1 und ap = 1: {count_kh_ki_ap[year]}")
    # Kombination von 'gen', 'ki' und 'ap'
    count_gen_ki_ap[year] = ((df_full['gen'] == 1) & (df_full['ki'] == 1) & (df_full['ap'] == 1) & df_full['kh'].isna()).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit gen = 1, ki = 1 und ap = 1: {count_gen_ki_ap[year]}")
    # Kombination von 'gen', 'ki' und 'ap' und 'kh'
    count_gen_ki_ap_kh[year] = ((df_full['gen'] == 1) & (df_full['ki'] == 1) & (df_full['ap'] == 1) & (df_full['kh'] == 1)).sum()
    print(f"Anzahl der Einträge in Jahr {year} mit gen = 1, ki = 1, ap = 1 und kh = 1: {count_gen_ki_ap_kh[year]}")
    print("Check:")
    count_vars_unique[year] = [
        count_kh_gen[year],     # 'kh=1', 'gen=1'
        count_kh_ki[year],      # 'kh=1', 'ki=1'
        count_kh_ap[year],      # 'kh=1', 'ap=1'

        count_gen_ki[year],     # 'gen=1', 'ki=1'
        count_gen_ap[year],     # 'gen=1', 'ap=1'

        count_ki_ap[year]      # 'ki=1', 'ap=1'
    ]
    count_zweier[year] = sum(count_vars_unique[year])
    count_einser[year] = count_kh_oza[year]+ count_gen_oza[year]+count_ki_oza[year]+count_ap_oza[year]
    count_dreier[year] = count_kh_gen_ki[year]+count_kh_gen_ap[year]+count_kh_ki_ap[year]+count_gen_ki_ap[year]
    # Zeige die Gesamtsumme an
    print(f"Die Gesamtsumme aller 1er in Jahr {year}: {count_einser[year]}")
    print(f"Die Gesamtsumme aller 2er-kombis in Jahr {year}: {count_zweier[year]}")
    print(f"Die Gesamtsumme aller 3er-kombis in Jahr {year}: {count_dreier[year]}")
    print(f"Die Gesamtsumme der 4er-Kombi in Jahr {year}: {count_gen_ki_ap_kh[year]}")
    total_count[year] = count_einser[year]+count_zweier[year]+count_dreier[year]+count_gen_ki_ap_kh[year]
    total_nan[year] = total_count[year]+fehler[year]
    # Zeige die Summe an
    print(f"Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr {year} ist: {total_count[year]}")
    print(f"Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr {year} ist: {total_nan[year]}")
    print(f"Stellenanzeigen insgesamt: {count_all_oza[year]} (Muss gleich sein wie zeile darüber!)\n")
    timestamps = [datetime.strptime(date, "%Y-%m-%d") for date in df_full["date"]]
    months = {(ts.year, ts.month) for ts in timestamps}
    all_months.update(months)
    all_years.add(year)
    year_counts[year] = year_counts.get(year, 0) + len(timestamps) 
    for ts in timestamps:
        key = (ts.year, ts.month)
        month_counts[key] = month_counts.get(key, 0) + 1
    del df_full
# Out:
# NaN-Fehler in Jahr 2016: 263
# Stellenanzeigen in 2016 insgesamt: 46628
# Stellenanzeigen in 2016 nur mit generalistischen Berufsbezeichnungen: 1439
# Stellenanzeigen in 2016 nur mit Berufsbezeichnungen der Akutpflege: 12879
# Stellenanzeigen in 2016 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 1470
# Stellenanzeigen in 2016 nur mit Berufsbezeichnungen der Altenpflege: 7046
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2016 mit kh = 1 und gen = 1: 1256
# Anzahl der Einträge in Jahr 2016 mit kh = 1 und ki = 1: 1845
# Anzahl der Einträge in Jahr 2016 mit kh = 1 und ap = 1: 10050
# Anzahl der Einträge in Jahr 2016 mit gen = 1 und ki = 1: 27
# Anzahl der Einträge in Jahr 2016 mit gen = 1 und ap = 1: 1032
# Anzahl der Einträge in Jahr 2016 mit ki = 1 und ap = 1: 87
# Anzahl der Einträge in Jahr 2016 mit kh = 1, gen = 1 und ki = 1: 246
# Anzahl der Einträge in Jahr 2016 mit kh = 1, gen = 1 und ap = 1: 4642
# Anzahl der Einträge in Jahr 2016 mit kh = 1, ki = 1 und ap = 1: 2615
# Anzahl der Einträge in Jahr 2016 mit gen = 1, ki = 1 und ap = 1: 26
# Anzahl der Einträge in Jahr 2016 mit gen = 1, ki = 1, ap = 1 und kh = 1: 1705
# Check:
# Die Gesamtsumme aller 1er in Jahr 2016: 22834
# Die Gesamtsumme aller 2er-kombis in Jahr 2016: 14297
# Die Gesamtsumme aller 3er-kombis in Jahr 2016: 7529
# Die Gesamtsumme der 4er-Kombi in Jahr 2016: 1705
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2016 ist: 46365
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2016 ist: 46628
# Stellenanzeigen insgesamt: 46628 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2017: 335
# Stellenanzeigen in 2017 insgesamt: 63283
# Stellenanzeigen in 2017 nur mit generalistischen Berufsbezeichnungen: 1648
# Stellenanzeigen in 2017 nur mit Berufsbezeichnungen der Akutpflege: 15068
# Stellenanzeigen in 2017 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 1650
# Stellenanzeigen in 2017 nur mit Berufsbezeichnungen der Altenpflege: 9824
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2017 mit kh = 1 und gen = 1: 1158
# Anzahl der Einträge in Jahr 2017 mit kh = 1 und ki = 1: 2339
# Anzahl der Einträge in Jahr 2017 mit kh = 1 und ap = 1: 15100
# Anzahl der Einträge in Jahr 2017 mit gen = 1 und ki = 1: 57
# Anzahl der Einträge in Jahr 2017 mit gen = 1 und ap = 1: 1471
# Anzahl der Einträge in Jahr 2017 mit ki = 1 und ap = 1: 121
# Anzahl der Einträge in Jahr 2017 mit kh = 1, gen = 1 und ki = 1: 281
# Anzahl der Einträge in Jahr 2017 mit kh = 1, gen = 1 und ap = 1: 7608
# Anzahl der Einträge in Jahr 2017 mit kh = 1, ki = 1 und ap = 1: 3841
# Anzahl der Einträge in Jahr 2017 mit gen = 1, ki = 1 und ap = 1: 70
# Anzahl der Einträge in Jahr 2017 mit gen = 1, ki = 1, ap = 1 und kh = 1: 2712
# Check:
# Die Gesamtsumme aller 1er in Jahr 2017: 28190
# Die Gesamtsumme aller 2er-kombis in Jahr 2017: 20246
# Die Gesamtsumme aller 3er-kombis in Jahr 2017: 11800
# Die Gesamtsumme der 4er-Kombi in Jahr 2017: 2712
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2017 ist: 62948
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2017 ist: 63283
# Stellenanzeigen insgesamt: 63283 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2018: 381
# Stellenanzeigen in 2018 insgesamt: 81390
# Stellenanzeigen in 2018 nur mit generalistischen Berufsbezeichnungen: 3923
# Stellenanzeigen in 2018 nur mit Berufsbezeichnungen der Akutpflege: 22093
# Stellenanzeigen in 2018 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 2026
# Stellenanzeigen in 2018 nur mit Berufsbezeichnungen der Altenpflege: 11263
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2018 mit kh = 1 und gen = 1: 2016
# Anzahl der Einträge in Jahr 2018 mit kh = 1 und ki = 1: 2333
# Anzahl der Einträge in Jahr 2018 mit kh = 1 und ap = 1: 17157
# Anzahl der Einträge in Jahr 2018 mit gen = 1 und ki = 1: 106
# Anzahl der Einträge in Jahr 2018 mit gen = 1 und ap = 1: 5377
# Anzahl der Einträge in Jahr 2018 mit ki = 1 und ap = 1: 92
# Anzahl der Einträge in Jahr 2018 mit kh = 1, gen = 1 und ki = 1: 226
# Anzahl der Einträge in Jahr 2018 mit kh = 1, gen = 1 und ap = 1: 8164
# Anzahl der Einträge in Jahr 2018 mit kh = 1, ki = 1 und ap = 1: 3794
# Anzahl der Einträge in Jahr 2018 mit gen = 1, ki = 1 und ap = 1: 45
# Anzahl der Einträge in Jahr 2018 mit gen = 1, ki = 1, ap = 1 und kh = 1: 2394
# Check:
# Die Gesamtsumme aller 1er in Jahr 2018: 39305
# Die Gesamtsumme aller 2er-kombis in Jahr 2018: 27081
# Die Gesamtsumme aller 3er-kombis in Jahr 2018: 12229
# Die Gesamtsumme der 4er-Kombi in Jahr 2018: 2394
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2018 ist: 81009
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2018 ist: 81390
# Stellenanzeigen insgesamt: 81390 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2019: 667
# Stellenanzeigen in 2019 insgesamt: 144501
# Stellenanzeigen in 2019 nur mit generalistischen Berufsbezeichnungen: 9148
# Stellenanzeigen in 2019 nur mit Berufsbezeichnungen der Akutpflege: 34355
# Stellenanzeigen in 2019 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 2738
# Stellenanzeigen in 2019 nur mit Berufsbezeichnungen der Altenpflege: 15978
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2019 mit kh = 1 und gen = 1: 9940
# Anzahl der Einträge in Jahr 2019 mit kh = 1 und ki = 1: 3362
# Anzahl der Einträge in Jahr 2019 mit kh = 1 und ap = 1: 29445
# Anzahl der Einträge in Jahr 2019 mit gen = 1 und ki = 1: 514
# Anzahl der Einträge in Jahr 2019 mit gen = 1 und ap = 1: 10456
# Anzahl der Einträge in Jahr 2019 mit ki = 1 und ap = 1: 134
# Anzahl der Einträge in Jahr 2019 mit kh = 1, gen = 1 und ki = 1: 380
# Anzahl der Einträge in Jahr 2019 mit kh = 1, gen = 1 und ap = 1: 16508
# Anzahl der Einträge in Jahr 2019 mit kh = 1, ki = 1 und ap = 1: 6680
# Anzahl der Einträge in Jahr 2019 mit gen = 1, ki = 1 und ap = 1: 125
# Anzahl der Einträge in Jahr 2019 mit gen = 1, ki = 1, ap = 1 und kh = 1: 4071
# Check:
# Die Gesamtsumme aller 1er in Jahr 2019: 62219
# Die Gesamtsumme aller 2er-kombis in Jahr 2019: 53851
# Die Gesamtsumme aller 3er-kombis in Jahr 2019: 23693
# Die Gesamtsumme der 4er-Kombi in Jahr 2019: 4071
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2019 ist: 143834
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2019 ist: 144501
# Stellenanzeigen insgesamt: 144501 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2020: 1065
# Stellenanzeigen in 2020 insgesamt: 140567
# Stellenanzeigen in 2020 nur mit generalistischen Berufsbezeichnungen: 16234
# Stellenanzeigen in 2020 nur mit Berufsbezeichnungen der Akutpflege: 37711
# Stellenanzeigen in 2020 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 3411
# Stellenanzeigen in 2020 nur mit Berufsbezeichnungen der Altenpflege: 12594
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2020 mit kh = 1 und gen = 1: 4646
# Anzahl der Einträge in Jahr 2020 mit kh = 1 und ki = 1: 3845
# Anzahl der Einträge in Jahr 2020 mit kh = 1 und ap = 1: 21673
# Anzahl der Einträge in Jahr 2020 mit gen = 1 und ki = 1: 305
# Anzahl der Einträge in Jahr 2020 mit gen = 1 und ap = 1: 8487
# Anzahl der Einträge in Jahr 2020 mit ki = 1 und ap = 1: 146
# Anzahl der Einträge in Jahr 2020 mit kh = 1, gen = 1 und ki = 1: 518
# Anzahl der Einträge in Jahr 2020 mit kh = 1, gen = 1 und ap = 1: 19180
# Anzahl der Einträge in Jahr 2020 mit kh = 1, ki = 1 und ap = 1: 4033
# Anzahl der Einträge in Jahr 2020 mit gen = 1, ki = 1 und ap = 1: 436
# Anzahl der Einträge in Jahr 2020 mit gen = 1, ki = 1, ap = 1 und kh = 1: 6283
# Check:
# Die Gesamtsumme aller 1er in Jahr 2020: 69950
# Die Gesamtsumme aller 2er-kombis in Jahr 2020: 39102
# Die Gesamtsumme aller 3er-kombis in Jahr 2020: 24167
# Die Gesamtsumme der 4er-Kombi in Jahr 2020: 6283
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2020 ist: 139502
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2020 ist: 140567
# Stellenanzeigen insgesamt: 140567 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2021: 733
# Stellenanzeigen in 2021 insgesamt: 130105
# Stellenanzeigen in 2021 nur mit generalistischen Berufsbezeichnungen: 23652
# Stellenanzeigen in 2021 nur mit Berufsbezeichnungen der Akutpflege: 31693
# Stellenanzeigen in 2021 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 2383
# Stellenanzeigen in 2021 nur mit Berufsbezeichnungen der Altenpflege: 8577
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2021 mit kh = 1 und gen = 1: 5300
# Anzahl der Einträge in Jahr 2021 mit kh = 1 und ki = 1: 3312
# Anzahl der Einträge in Jahr 2021 mit kh = 1 und ap = 1: 17533
# Anzahl der Einträge in Jahr 2021 mit gen = 1 und ki = 1: 396
# Anzahl der Einträge in Jahr 2021 mit gen = 1 und ap = 1: 8326
# Anzahl der Einträge in Jahr 2021 mit ki = 1 und ap = 1: 84
# Anzahl der Einträge in Jahr 2021 mit kh = 1, gen = 1 und ki = 1: 586
# Anzahl der Einträge in Jahr 2021 mit kh = 1, gen = 1 und ap = 1: 17332
# Anzahl der Einträge in Jahr 2021 mit kh = 1, ki = 1 und ap = 1: 3938
# Anzahl der Einträge in Jahr 2021 mit gen = 1, ki = 1 und ap = 1: 568
# Anzahl der Einträge in Jahr 2021 mit gen = 1, ki = 1, ap = 1 und kh = 1: 5692
# Check:
# Die Gesamtsumme aller 1er in Jahr 2021: 66305
# Die Gesamtsumme aller 2er-kombis in Jahr 2021: 34951
# Die Gesamtsumme aller 3er-kombis in Jahr 2021: 22424
# Die Gesamtsumme der 4er-Kombi in Jahr 2021: 5692
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2021 ist: 129372
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2021 ist: 130105
# Stellenanzeigen insgesamt: 130105 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2022: 458
# Stellenanzeigen in 2022 insgesamt: 162309
# Stellenanzeigen in 2022 nur mit generalistischen Berufsbezeichnungen: 46582
# Stellenanzeigen in 2022 nur mit Berufsbezeichnungen der Akutpflege: 27109
# Stellenanzeigen in 2022 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 2125
# Stellenanzeigen in 2022 nur mit Berufsbezeichnungen der Altenpflege: 7791
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2022 mit kh = 1 und gen = 1: 8757
# Anzahl der Einträge in Jahr 2022 mit kh = 1 und ki = 1: 2721
# Anzahl der Einträge in Jahr 2022 mit kh = 1 und ap = 1: 16619
# Anzahl der Einträge in Jahr 2022 mit gen = 1 und ki = 1: 489
# Anzahl der Einträge in Jahr 2022 mit gen = 1 und ap = 1: 11356
# Anzahl der Einträge in Jahr 2022 mit ki = 1 und ap = 1: 86
# Anzahl der Einträge in Jahr 2022 mit kh = 1, gen = 1 und ki = 1: 756
# Anzahl der Einträge in Jahr 2022 mit kh = 1, gen = 1 und ap = 1: 25272
# Anzahl der Einträge in Jahr 2022 mit kh = 1, ki = 1 und ap = 1: 4024
# Anzahl der Einträge in Jahr 2022 mit gen = 1, ki = 1 und ap = 1: 423
# Anzahl der Einträge in Jahr 2022 mit gen = 1, ki = 1, ap = 1 und kh = 1: 7741
# Check:
# Die Gesamtsumme aller 1er in Jahr 2022: 83607
# Die Gesamtsumme aller 2er-kombis in Jahr 2022: 40028
# Die Gesamtsumme aller 3er-kombis in Jahr 2022: 30475
# Die Gesamtsumme der 4er-Kombi in Jahr 2022: 7741
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2022 ist: 161851
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2022 ist: 162309
# Stellenanzeigen insgesamt: 162309 (Muss gleich sein wie zeile darüber!)
#
# NaN-Fehler in Jahr 2023: 660
# Stellenanzeigen in 2023 insgesamt: 164030
# Stellenanzeigen in 2023 nur mit generalistischen Berufsbezeichnungen: 51814
# Stellenanzeigen in 2023 nur mit Berufsbezeichnungen der Akutpflege: 22100
# Stellenanzeigen in 2023 nur mit Berufsbezeichnungen der Kinderkrankenpflege: 1907
# Stellenanzeigen in 2023 nur mit Berufsbezeichnungen der Altenpflege: 7098
#
# Jetzt filtern:
# Anzahl der Einträge in Jahr 2023 mit kh = 1 und gen = 1: 10582
# Anzahl der Einträge in Jahr 2023 mit kh = 1 und ki = 1: 2104
# Anzahl der Einträge in Jahr 2023 mit kh = 1 und ap = 1: 12364
# Anzahl der Einträge in Jahr 2023 mit gen = 1 und ki = 1: 772
# Anzahl der Einträge in Jahr 2023 mit gen = 1 und ap = 1: 15546
# Anzahl der Einträge in Jahr 2023 mit ki = 1 und ap = 1: 45
# Anzahl der Einträge in Jahr 2023 mit kh = 1, gen = 1 und ki = 1: 1251
# Anzahl der Einträge in Jahr 2023 mit kh = 1, gen = 1 und ap = 1: 26451
# Anzahl der Einträge in Jahr 2023 mit kh = 1, ki = 1 und ap = 1: 2255
# Anzahl der Einträge in Jahr 2023 mit gen = 1, ki = 1 und ap = 1: 853
# Anzahl der Einträge in Jahr 2023 mit gen = 1, ki = 1, ap = 1 und kh = 1: 8228
# Check:
# Die Gesamtsumme aller 1er in Jahr 2023: 82919
# Die Gesamtsumme aller 2er-kombis in Jahr 2023: 41413
# Die Gesamtsumme aller 3er-kombis in Jahr 2023: 30810
# Die Gesamtsumme der 4er-Kombi in Jahr 2023: 8228
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi in Jahr 2023 ist: 163370
# Die Gesamtsumme aller 1er, 2er, 3er-kombis + der 4er-kombi + NaN-Fehler in Jahr 2023 ist: 164030
# Stellenanzeigen insgesamt: 164030 (Muss gleich sein wie zeile darüber!)

# %%
for year in years:
    # Erstelle eine Kreuztabelle mit den Variablen als Zeilen und Spalten
    crosstab_matrix = pd.DataFrame(index=['kh=1', 'gen=1', 'ki=1', 'ap=1'],
                                   columns=['kh=1', 'gen=1', 'ki=1', 'ap=1'], dtype=int)
    # Füge die Häufigkeiten basierend auf den Kombinationen hinzu
    crosstab_matrix.loc['kh=1', 'gen=1'] = count_kh_gen[year]
    crosstab_matrix.loc['kh=1', 'ki=1'] = count_kh_ki[year]
    crosstab_matrix.loc['kh=1', 'ap=1'] = count_kh_ap[year]
    crosstab_matrix.loc['kh=1', 'kh=1'] = count_kh_oza[year]

    crosstab_matrix.loc['gen=1', 'ki=1'] = count_gen_ki[year]
    crosstab_matrix.loc['gen=1', 'ap=1'] = count_gen_ap[year]
    crosstab_matrix.loc['gen=1', 'kh=1'] = count_kh_gen[year]
    crosstab_matrix.loc['gen=1', 'gen=1'] = count_gen_oza[year]

    crosstab_matrix.loc['ki=1', 'ap=1'] = count_ki_ap[year]
    crosstab_matrix.loc['ki=1', 'kh=1'] = count_kh_ki[year]
    crosstab_matrix.loc['ki=1', 'ki=1'] = count_ki_oza[year]
    crosstab_matrix.loc['ki=1', 'gen=1'] = count_gen_ki[year]

    crosstab_matrix.loc['ap=1', 'gen=1'] = count_gen_ap[year] 
    crosstab_matrix.loc['ap=1', 'ki=1'] = count_ki_ap[year]
    crosstab_matrix.loc['ap=1', 'ap=1'] = count_ap_oza[year]
    crosstab_matrix.loc['ap=1', 'kh=1'] = count_kh_ap[year]

    crosstab_matrix['Row Total'] = crosstab_matrix.sum(axis=1)
    crosstab_matrix.loc['Column Total'] = crosstab_matrix.sum(axis=0)
    # Zeige die Kreuztabelle an
    print(f"Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr {year}")
    print(crosstab_matrix)
    print("")
# Out:
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2016
#                  kh=1   gen=1    ki=1     ap=1  Row Total
# kh=1          12879.0  1256.0  1845.0  10050.0    26030.0
# gen=1          1256.0  1439.0    27.0   1032.0     3754.0
# ki=1           1845.0    27.0  1470.0     87.0     3429.0
# ap=1          10050.0  1032.0    87.0   7046.0    18215.0
# Column Total  26030.0  3754.0  3429.0  18215.0    51428.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2017
#                  kh=1   gen=1    ki=1     ap=1  Row Total
# kh=1          15068.0  1158.0  2339.0  15100.0    33665.0
# gen=1          1158.0  1648.0    57.0   1471.0     4334.0
# ki=1           2339.0    57.0  1650.0    121.0     4167.0
# ap=1          15100.0  1471.0   121.0   9824.0    26516.0
# Column Total  33665.0  4334.0  4167.0  26516.0    68682.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2018
#                  kh=1    gen=1    ki=1     ap=1  Row Total
# kh=1          22093.0   2016.0  2333.0  17157.0    43599.0
# gen=1          2016.0   3923.0   106.0   5377.0    11422.0
# ki=1           2333.0    106.0  2026.0     92.0     4557.0
# ap=1          17157.0   5377.0    92.0  11263.0    33889.0
# Column Total  43599.0  11422.0  4557.0  33889.0    93467.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2019
#                  kh=1    gen=1    ki=1     ap=1  Row Total
# kh=1          34355.0   9940.0  3362.0  29445.0    77102.0
# gen=1          9940.0   9148.0   514.0  10456.0    30058.0
# ki=1           3362.0    514.0  2738.0    134.0     6748.0
# ap=1          29445.0  10456.0   134.0  15978.0    56013.0
# Column Total  77102.0  30058.0  6748.0  56013.0   169921.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2020
#                  kh=1    gen=1    ki=1     ap=1  Row Total
# kh=1          37711.0   4646.0  3845.0  21673.0    67875.0
# gen=1          4646.0  16234.0   305.0   8487.0    29672.0
# ki=1           3845.0    305.0  3411.0    146.0     7707.0
# ap=1          21673.0   8487.0   146.0  12594.0    42900.0
# Column Total  67875.0  29672.0  7707.0  42900.0   148154.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2021
#                  kh=1    gen=1    ki=1     ap=1  Row Total
# kh=1          31693.0   5300.0  3312.0  17533.0    57838.0
# gen=1          5300.0  23652.0   396.0   8326.0    37674.0
# ki=1           3312.0    396.0  2383.0     84.0     6175.0
# ap=1          17533.0   8326.0    84.0   8577.0    34520.0
# Column Total  57838.0  37674.0  6175.0  34520.0   136207.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2022
#                  kh=1    gen=1    ki=1     ap=1  Row Total
# kh=1          27109.0   8757.0  2721.0  16619.0    55206.0
# gen=1          8757.0  46582.0   489.0  11356.0    67184.0
# ki=1           2721.0    489.0  2125.0     86.0     5421.0
# ap=1          16619.0  11356.0    86.0   7791.0    35852.0
# Column Total  55206.0  67184.0  5421.0  35852.0   163663.0
#
# Kreuztabelle: Überschneidungen der Berufsbezeichnungen im Jahr 2023
#                  kh=1    gen=1    ki=1     ap=1  Row Total
# kh=1          22100.0  10582.0  2104.0  12364.0    47150.0
# gen=1         10582.0  51814.0   772.0  15546.0    78714.0
# ki=1           2104.0    772.0  1907.0     45.0     4828.0
# ap=1          12364.0  15546.0    45.0   7098.0    35053.0
# Column Total  47150.0  78714.0  4828.0  35053.0   165745.0

# %%
# Für alle Jahre + für pre-2020 + für post-2020 + einmal nur für 2023 (ab da gibts Generalisten)
# Zuerst Abfragen, welche Jahre in years-Liste sind!
count_kh_sub = 0
count_ap_sub = 0
count_kh_ki_sub = 0
count_ki_sub = 0
count_kh_ki_sub = 0
count_ki_ap_sub = 0
count_kh_ki_ap_sub = 0
count_kh_ap_sub = 0
count_kh_post = 0
count_ap_post = 0
count_gen_post = 0
count_kh_post_sub = 0
count_kh_gen_ki_sub = 0
count_kh_gen_ap_sub = 0
count_kh_ki_ap_sub = 0 
count_gen_ki_ap_sub = 0
count_gen_ki_ap_kh_sub = 0
count_all_oza_sub = 0
count_kh_gen_post = 0
count_ki_post = 0
count_kh_ki_post = 0
count_ki_ap_post = 0
count_kh_ki_ap_post = 0
count_kh_ap_post = 0
count_gen_sub = 0
count_kh_gen_sub = 0
count_kh_ap_sub = 0
count_gen_ki_sub = 0
count_gen_ki_post = 0
count_gen_ap_sub = 0
count_gen_ap_post = 0
count_kh_gen_ki_post = 0
count_kh_gen_ap_post = 0
count_kh_ki_ap_post = 0 
count_gen_ki_ap_post = 0
count_gen_ki_ap_kh_post = 0
count_all_oza_post = 0
count_kh_sub_all = 0
count_ki_sub_all = 0
count_ap_sub_all = 0
count_gen_sub_all = 0
count_kh_post_all = 0
count_ki_post_all = 0
count_ap_post_all = 0
count_gen_post_all = 0
int_years = list(map(int, years))
for yearint in int_years:
    year = str(yearint)
    fig, ax = plt.subplots(figsize=(8, 6))  # Erstelle ein einzelnes Subplot
    venn3(
        subsets=(
            count_kh_oza[year],  # Nur kh
            count_ap_oza[year],  # Nur gen
            count_kh_ap[year],  # kh & gen
            count_ki_oza[year],  # Nur ki
            count_kh_ki[year],  # kh & ki
            count_ki_ap[year],  # gen & ki
            count_kh_ki_ap[year]  # kh & gen & ki
        ),
        set_labels=('Berufsbezeichnungen aus der Akutpflege', 'Berufsbezeichnungen aus der Altenpflege', 'Berufsbezeichnungen aus der Kinderkrankenpflege'),
        ax=ax  # Weisen wir das Diagramm dem Subplot zu
    )
    ax.set_title(f"Venn-Diagramm: Kombinationen von Berufsbezeichnungen im Jahr {year}")
    plt.show()
    if yearint < 2020:
        count_kh_sub += count_kh_oza[year]
        count_ap_sub += count_ap_oza[year]
        count_kh_ki_sub += count_kh_ki[year]
        count_ki_sub += count_ki_oza[year]
        count_kh_sub_all += count_all_kh[year]
        count_ki_sub_all += count_all_ki[year]
        count_ap_sub_all += count_all_ap[year]
        count_gen_sub_all += count_all_gen[year]
        count_ki_ap_sub += count_ki_ap[year]
        count_kh_ki_ap_sub += count_kh_ki_ap[year]
        count_kh_ap_sub += count_kh_ap[year]
        count_gen_sub += count_gen_oza[year]
        count_kh_gen_sub += count_kh_gen[year]
        count_gen_ki_sub += count_gen_ki[year]
        count_gen_ap_sub += count_gen_ap[year]
        count_kh_gen_ki_sub += count_kh_gen_ki[year] 
        count_kh_gen_ap_sub += count_kh_gen_ap[year] 
        count_gen_ki_ap_sub += count_gen_ki_ap[year] 
        count_gen_ki_ap_kh_sub += count_gen_ki_ap_kh[year]
        count_all_oza_sub += count_all_oza[year]
    if yearint >= 2020:
        count_kh_post += count_kh_oza[year]
        count_ap_post += count_ap_oza[year]
        count_ki_post += count_ki_oza[year]
        count_kh_post_all += count_all_kh[year]
        count_ki_post_all += count_all_ki[year]
        count_ap_post_all += count_all_ap[year]
        count_gen_post_all += count_all_gen[year]
        count_kh_ki_post += count_kh_ki[year]
        count_ki_ap_post += count_ki_ap[year]
        count_kh_ki_ap_post += count_kh_ki_ap[year]
        count_kh_ap_post += count_kh_ap[year]
        count_gen_post += count_gen_oza[year]
        count_kh_gen_post += count_kh_gen[year]
        count_gen_ki_post += count_gen_ki[year]
        count_gen_ap_post += count_gen_ap[year]
        count_kh_gen_ki_post += count_kh_gen_ki[year] 
        count_kh_gen_ap_post += count_kh_gen_ap[year] 
        count_gen_ki_ap_post += count_gen_ki_ap[year] 
        count_gen_ki_ap_kh_post += count_gen_ki_ap_kh[year]
        count_all_oza_post += count_all_oza[year]
if count_kh_sub >= 1:
    fig, ax = plt.subplots(figsize=(8, 6))  # Erstelle ein einzelnes Subplot
    venn3(
        subsets=(
            count_kh_sub,  # Nur kh
            count_ap_sub,  # Nur gen
            count_kh_ap_sub,  # kh & gen
            count_ki_sub,  # Nur ki
            count_kh_ki_sub,  # kh & ki
            count_ki_ap_sub,  # gen & ki
            count_kh_ki_ap_sub  # kh & gen & ki
        ),
        set_labels=('Berufsbezeichnungen aus der Akutpflege', 'Berufsbezeichnungen aus der Altenpflege', 'Berufsbezeichnungen aus der Kinderkrankenpflege'),
        ax=ax  # Weisen wir das Diagramm dem Subplot zu
    )
    ax.set_title("Venn-Diagramm: Kombinationen von Berufsbezeichnungen vor 2020")
    plt.show()
if count_kh_post >= 1:  
    fig, ax = plt.subplots(figsize=(8, 6))  # Erstelle ein einzelnes Subplot
    venn3(
        subsets=(
            count_kh_post,  # Nur kh
            count_ap_post,  # Nur gen
            count_kh_ap_post,  # kh & gen
            count_ki_post,  # Nur ki
            count_kh_ki_post,  # kh & ki
            count_ki_ap_post,  # gen & ki
            count_kh_ki_ap_post  # kh & gen & ki
        ),
        set_labels=('Berufsbezeichnungen aus der Akutpflege', 'Berufsbezeichnungen aus der Altenpflege', 'Berufsbezeichnungen aus der Kinderkrankenpflege'),
        ax=ax  # Weisen wir das Diagramm dem Subplot zu
    )
    ax.set_title("Venn-Diagramm: Kombinationen von Berufsbezeichnungen ab 2020")
    plt.show()

# %%
# für pre-2020 + für post-2020 + einmal nur für 2023 (ab da gibts Generalisten)
# Zuerst Abfragen, welche Jahre in years-Liste sind!
# Erstellen einer Figure mit 6 Subplots für die 2er-Kombinationen
if count_kh_sub >= 1:      
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    # Definition der 2er-Kombinationen und ihrer Werte
    combinations = [
        ("kh", "gen", count_kh_sub, count_gen_sub, count_kh_gen_sub),
        ("kh", "ki", count_kh_sub, count_ki_sub, count_kh_ki_sub),
        ("kh", "ap", count_kh_sub, count_ap_sub, count_kh_ap_sub),
        ("gen", "ki", count_gen_sub, count_ki_sub, count_gen_ki_sub),
        ("gen", "ap", count_gen_sub, count_ap_sub, count_gen_ap_sub),
        ("ki", "ap", count_ki_sub, count_ap_sub, count_ki_ap_sub)
    ]
    # Zeichnen der Venn-Diagramme
    for ax, (label1, label2, count1, count2, count_intersect) in zip(axes.flat, combinations):
        venn2(subsets=(count1, count2, count_intersect), set_labels=(label1, label2), ax=ax)
        ax.set_title(f"Venn-Diagramm vor 2020: {label1} & {label2}")
    plt.tight_layout()
    plt.show()
if count_kh_post >= 1: 
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    # Definition der 2er-Kombinationen und ihrer Werte
    combinations = [
        ("kh", "gen", count_kh_post, count_gen_post, count_kh_gen_post),
        ("kh", "ki", count_kh_post, count_ki_post, count_kh_ki_post),
        ("kh", "ap", count_kh_post, count_ap_post, count_kh_ap_post),
        ("gen", "ki", count_gen_post, count_ki_post, count_gen_ki_post),
        ("gen", "ap", count_gen_post, count_ap_post, count_gen_ap_post),
        ("ki", "ap", count_ki_post, count_ap_post, count_ki_ap_post)
    ]
    # Zeichnen der Venn-Diagramme
    for ax, (label1, label2, count1, count2, count_intersect) in zip(axes.flat, combinations):
        venn2(subsets=(count1, count2, count_intersect), set_labels=(label1, label2), ax=ax)
        ax.set_title(f"Venn-Diagramm ab 2020: {label1} & {label2}")
    plt.tight_layout()
    plt.show()
if "2023" in years:
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    # Definition der 2er-Kombinationen und ihrer Werte
    combinations = [
        ("kh", "gen", count_kh_oza["2023"], count_gen_oza["2023"], count_kh_gen["2023"]),
        ("kh", "ki", count_kh_oza["2023"], count_ki_oza["2023"], count_kh_ki["2023"]),
        ("kh", "ap", count_kh_oza["2023"], count_ap_oza["2023"], count_kh_ap["2023"]),
        ("gen", "ki", count_gen_oza["2023"], count_ki_oza["2023"], count_gen_ki["2023"]),
        ("gen", "ap", count_gen_oza["2023"], count_ap_oza["2023"], count_gen_ap["2023"]),
        ("ki", "ap", count_ki_oza["2023"], count_ap_oza["2023"], count_ki_ap["2023"])
    ]
    # Zeichnen der Venn-Diagramme
    for ax, (label1, label2, count1, count2, count_intersect) in zip(axes.flat, combinations):
        venn2(subsets=(count1, count2, count_intersect), set_labels=(label1, label2), ax=ax)
        ax.set_title(f"Venn-Diagramm nur 2023: {label1} & {label2}")
    plt.tight_layout()
    plt.show()

# %%
# Für alle Jahre + für pre-2020 + für post-2020 + einmal nur für 2023 (ab da gibts Generalisten)
# Zuerst Abfragen, welche Jahre in years-Liste sind!
# Werte für die vier Hauptkategorien und ihre Kombinationen
int_years = list(map(int, years))
for yearint in int_years:
    year = str(yearint)
    sizes = [
        count_gen_oza[year], count_kh_oza[year], count_ki_oza[year], count_ap_oza[year], 
        count_kh_gen[year], count_gen_ki[year], count_gen_ap[year], count_kh_ki[year], count_kh_ap[year], count_ki_ap[year], 
        count_kh_gen_ki[year], count_kh_gen_ap[year], count_kh_ki_ap[year], count_gen_ki_ap[year], count_all_oza[year]
    ]
    # Labels für das Diagramm
    labels = [
        "Nur Gen", "Nur KH", "Nur KI", "Nur AP",
        "Gen & KH", "Gen & KI", "Gen & AP", "KH & KI", "KH & AP", "KI & AP",
        "Gen & KH & KI", "Gen & KH & AP", "KH & KI & AP", "Gen & KI & AP", "Alle Gruppen"
    ]
    # Entferne Einträge mit Wert 0 für bessere Lesbarkeit
    filtered_sizes = [size for size in sizes if size > 0]
    filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
    # Erstelle das Tortendiagramm
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
    # Titel setzen
    ax.set_title(f"Verteilung der Berufsbezeichnungen nach Kombinationen im Jahr {year}")
    # Zeige das Diagramm
    plt.show()
if count_kh_sub >= 1:  
    sizes = [
        count_gen_sub, count_kh_sub, count_ki_sub, count_ap_sub, 
        count_kh_gen_sub, count_gen_ki_sub, count_gen_ap_sub, count_kh_ki_sub, count_kh_ap_sub, count_ki_ap_sub, 
        count_kh_gen_ki_sub, count_kh_gen_ap_sub, count_kh_ki_ap_sub, count_gen_ki_ap_sub, count_all_oza_sub
    ]
    # Labels für das Diagramm
    labels = [
        "Nur Gen", "Nur KH", "Nur KI", "Nur AP",
        "Gen & KH", "Gen & KI", "Gen & AP", "KH & KI", "KH & AP", "KI & AP",
        "Gen & KH & KI", "Gen & KH & AP", "KH & KI & AP", "Gen & KI & AP", "Alle Gruppen"
    ]
    # Entferne Einträge mit Wert 0 für bessere Lesbarkeit
    filtered_sizes = [size for size in sizes if size > 0]
    filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
    # Erstelle das Tortendiagramm
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
    # Titel setzen
    ax.set_title(f"Verteilung der Berufsbezeichnungen nach Kombinationen vor 2020")
    # Zeige das Diagramm
    plt.show()
sizes = [
    sum(count_gen_oza.values()), sum(count_kh_oza.values()), sum(count_ki_oza.values()), sum(count_ap_oza.values()), 
    sum(count_kh_gen.values()), sum(count_gen_ki.values()), sum(count_gen_ap.values()), sum(count_kh_ki.values()), sum(count_kh_ap.values()), sum(count_ki_ap.values()), 
    sum(count_kh_gen_ki.values()), sum(count_kh_gen_ap.values()), sum(count_kh_ki_ap.values()), sum(count_gen_ki_ap.values()), sum(count_all_oza.values())
]
# Labels für das Diagramm
labels = [
    "Nur Gen", "Nur KH", "Nur KI", "Nur AP",
    "Gen & KH", "Gen & KI", "Gen & AP", "KH & KI", "KH & AP", "KI & AP",
    "Gen & KH & KI", "Gen & KH & AP", "KH & KI & AP", "Gen & KI & AP", "Alle Gruppen"
]
# Entferne Einträge mit Wert 0 für bessere Lesbarkeit
filtered_sizes = [size for size in sizes if size > 0]
filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
# Erstelle das Tortendiagramm
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
# Titel setzen
ax.set_title(f"Verteilung der Berufsbezeichnungen nach Kombinationen insgesamt (alle Jahre)")
# Zeige das Diagramm
plt.show()

# %%
# Für alle Jahre
# Zuerst Abfragen, welche Jahre in years-Liste sind!
print("Die folgen Diagramme berücksichten adressierte Stellenanzeigen; wenn eine Stellenanzeige mehrere Gruppen adressiert,")
print("dann wird diese in beiden Gruppen gezählt!")
int_years = list(map(int, years))
for yearint in int_years:
    year = str(yearint)
    sizes = [count_all_gen[year], count_all_kh[year], count_all_ki[year], count_all_ap[year]]
    # Labels für das Diagramm
    labels = ["Generalistische Berufsbezeichnungen", "Berufsbezeichnungen der Akutpflege", "Berufsbezeichnungen der Kinderkrankenpflege", "Berufsbezeichnungen der Altenpflege"]
    # Entferne Einträge mit Wert 0 für bessere Lesbarkeit
    filtered_sizes = [size for size in sizes if size > 0]
    filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
    # Erstelle das Tortendiagramm
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
    # Titel setzen
    ax.set_title(f"Anzahl der Stellenanzeigen, in denen die Berufsbezeichnungen angesprochen werden im Jahr {year}")
    # Zeige das Diagramm
    plt.show()
if count_kh_sub >= 1:
    year = str(yearint)
    sizes = [count_gen_sub_all, count_kh_sub_all, count_ki_sub_all, count_ap_sub_all]
    # Labels für das Diagramm
    labels = ["Generalistische Berufsbezeichnungen", "Berufsbezeichnungen der Akutpflege", "Berufsbezeichnungen der Kinderkrankenpflege", "Berufsbezeichnungen der Altenpflege"]
    # Entferne Einträge mit Wert 0 für bessere Lesbarkeit
    filtered_sizes = [size for size in sizes if size > 0]
    filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
    # Erstelle das Tortendiagramm
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
    # Titel setzen
    ax.set_title("Anzahl der Stellenanzeigen, in denen die Berufsbezeichnungen angesprochen werden vor 2020")
    # Zeige das Diagramm
    plt.show()
if count_kh_post >= 1:
    year = str(yearint)
    sizes = [count_gen_post_all, count_kh_post_all, count_ki_post_all, count_ap_post_all]
    # Labels für das Diagramm
    labels = ["Generalistische Berufsbezeichnungen", "Berufsbezeichnungen der Akutpflege", "Berufsbezeichnungen der Kinderkrankenpflege", "Berufsbezeichnungen der Altenpflege"]
    # Entferne Einträge mit Wert 0 für bessere Lesbarkeit
    filtered_sizes = [size for size in sizes if size > 0]
    filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
    # Erstelle das Tortendiagramm
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
    # Titel setzen
    ax.set_title("Anzahl der Stellenanzeigen, in denen die Berufsbezeichnungen angesprochen werden nach 2020")
    # Zeige das Diagramm
    plt.show()
year = str(yearint)
sizes = [sum(count_all_gen.values()), sum(count_all_kh.values()), sum(count_all_ki.values()), sum(count_all_ap.values())]
# Labels für das Diagramm
labels = ["Generalistische Berufsbezeichnungen", "Berufsbezeichnungen der Akutpflege", "Berufsbezeichnungen der Kinderkrankenpflege", "Berufsbezeichnungen der Altenpflege"]
# Entferne Einträge mit Wert 0 für bessere Lesbarkeit
filtered_sizes = [size for size in sizes if size > 0]
filtered_labels = [label for size, label in zip(sizes, labels) if size > 0]
# Erstelle das Tortendiagramm
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(filtered_sizes, labels=filtered_labels, autopct='%1.1f%%', startangle=140)
# Titel setzen
ax.set_title("Anzahl der Stellenanzeigen, in denen die Berufsbezeichnungen angesprochen insgesamt (alle Jahre)")
# Zeige das Diagramm
plt.show()
# Out:
# Die folgen Diagramme berücksichten adressierte Stellenanzeigen; wenn eine Stellenanzeige mehrere Gruppen adressiert,
# dann wird diese in beiden Gruppen gezählt!

# %%
# Bar: Alle SteA pro Monat --> absolut
# Für alle Jahre
sorted_months = sorted(all_months)
month_labels = [datetime(year, month, 1).strftime("%b %Y") for year, month in sorted_months]
xmonths = np.arange(len(month_labels))
ymonths = [month_counts.get(month, 0) for month in sorted_months]
yearsfc = sorted(set(year for year, month in sorted_months))
cmap = plt.colormaps.get_cmap('tab10')
colors = [cmap(i / max(1, len(yearsfc) - 1)) for i in range(len(yearsfc))]
year_color_map = {year: colors[i] for i, year in enumerate(yearsfc)}
bar_colors = [year_color_map[year] for year, month in sorted_months]
fig, ax = plt.subplots(figsize=(16, 8), constrained_layout=True)
barone = ax.bar(xmonths, ymonths, color=bar_colors, edgecolor='black')
# Werte über die Balken schreiben
for rect in barone:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.5, str(height), 
            ha='center', va='bottom')
ax.set_xticks(xmonths)
ax.set_xticklabels(month_labels, rotation=45, ha='right')
ax.set_xlabel('Monate')
ax.set_ylabel('Anzahl Stellenanzeigen')
ax.set_title('Stellenanzeigen pro Monat über alle Jahre')
handles = [plt.Line2D([0], [0], color=year_color_map[year], lw=4) for year in yearsfc]
ax.legend(handles, yearsfc, title="Jahr", loc="upper left")
plt.show()

# %%
# Bar: Alle SteA pro Jahr absolut
bar_colors = ["red", "blue", "green", "orange", "purple", "cyan", "brown", "pink", "lime", "yellow"]
sorted_years = sorted(all_years)
sorted_year_counts = [year_counts.get(year, 0) for year in sorted_years]
xyears = np.arange(len(sorted_years))
yyears = [year_counts.get(year, 0) for year in all_years]  # Fehlende Jahre = 0
fig, ax = plt.subplots(figsize=(16, 8), constrained_layout=True)
bartwo = ax.bar(xyears, sorted_year_counts, color=bar_colors, edgecolor='black')
# Werte über die Balken schreiben
for rect in bartwo:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 0.5, str(height), 
            ha='center', va='bottom')
ax.set_xticks(xyears)
ax.set_xticklabels(sorted_years, rotation=45, ha='right')
ax.set_xlabel('Jahre')
ax.set_ylabel('Anzahl Stellenanzeigen')
ax.set_title('Stellenanzeigen pro Jahr über mehrere Jahre')
plt.show()

# %%
# Bar: SteA pro Jahr nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> absolut
bar_colors = ["blue", "red"]
xyears = np.arange(len(all_years))
add_ap = []
add_kh = []
add_ki = []
add_gen = []
add_all = []
add_all_gen = []
add_all_kh = []
add_all_ki = []
add_all_ap = []
width = 0.2  # the width of the bars
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
int_years = list(map(int, years))
for yearint in int_years:
    year = str(yearint)
    add_ap.append(count_ap_oza[year])
    add_kh.append(count_kh_oza[year])
    add_ki.append(count_ki_oza[year])
    add_gen.append(count_gen_oza[year])
    add_all.append(count_all_oza[year])
    add_all_gen.append(count_all_gen[year]-count_gen_oza[year])
    add_all_kh.append(count_all_kh[year]-count_kh_oza[year])
    add_all_ki.append(count_all_ki[year]-count_ki_oza[year])
    add_all_ap.append(count_all_ap[year]-count_ap_oza[year])
rects1 = ax.bar(xyears - 1.5*width, add_gen, width, label='Nur Generalistische Berufsbezeichnungen')
rects2 = ax.bar(xyears - 0.5*width, add_kh, width, label='Nur Berufsbezeichnungen der Akutpflege')
rects3 = ax.bar(xyears + 0.5*width, add_ki, width, label='Nur Berufsbezeichnungen der Kinderkrankenpflege')
rects4 = ax.bar(xyears + 1.5*width, add_ap, width, label='Nur Berufsbezeichnungen der Altenpflege')
rects1_stack = ax.bar(xyears - 1.5*width, add_all_gen, width, bottom=add_gen, label='Generalistische Berufsbezeichnungen + Andere')
rects2_stack = ax.bar(xyears - 0.5*width, add_all_kh, width, bottom=add_kh, label='Berufsbezeichnungen der Akutpflege +  Andere')
rects3_stack = ax.bar(xyears + 0.5*width, add_all_ki, width, bottom=add_ki, label='Berufsbezeichnungen der Kinderkrankenpflege +  Andere')
rects4_stack = ax.bar(xyears + 1.5*width, add_all_ap, width, bottom=add_ap, label='Berufsbezeichnungen der Altenpflege +  Andere')
ax.plot(xyears, add_all, marker='o', color='black', label='Gesamt')
# Function to add text inside bars
def add_bar_labels(rect_base, rect_stack):
    for rect in rect_base:
        height = rect.get_height()
        ax.text(
            rect.get_x() + rect.get_width() / 2, 
            height - 0.5,  # Inside the base bar
            str(int(height)), 
            ha='center', va='top', color='black', fontsize=10, fontweight='bold'
        )
    for rect_b, rect_s in zip(rect_base, rect_stack):
        total_height = rect_b.get_height() + rect_s.get_height()  # Stacked height
        ax.text(
            rect_s.get_x() + rect_s.get_width() / 2, 
            total_height - 0.5,  # Inside the stacked bar
            str(int(rect_s.get_height())),  # Show only the value of the stacked bar
            ha='center', va='top', color='black', fontsize=10, fontweight='bold'
        )
    # Label for total (base + stacked) bars, positioned outside the stacked bar
    for rect_b, rect_s in zip(rect_base, rect_stack):
        total_height = rect_b.get_height() + rect_s.get_height()
        ax.text(
            rect_s.get_x() + rect_s.get_width() / 2, 
            total_height + 0.5,  # Positioning the label outside the stacked bar (above)
            str(round(total_height, 2)),  # Show the total value
            ha='center', va='bottom', color='black', fontsize=10, fontweight='bold'
        )
add_bar_labels(rects1, rects1_stack)
add_bar_labels(rects2, rects2_stack)
add_bar_labels(rects3, rects3_stack)
add_bar_labels(rects4, rects4_stack)
ax.set_xlabel('Jahre')
ax.set_ylabel('Anzahl Stellenanzeigen')
ax.set_title('Stellenanzeigen pro Jahr nach Art der Berufsbezeichnung')
ax.set_xticks(xyears)
ax.set_xticklabels(years)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Bar: SteA pro Jahr nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> relativ
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
# Umwandlung in Prozent
totals = np.array(add_gen) + np.array(add_kh) + np.array(add_ki) + np.array(add_ap) + np.array(add_all_gen) + np.array(add_all_kh) + np.array(add_all_ki) + np.array(add_all_ap)
percent_gen = np.array(add_gen) / totals * 100
percent_kh = np.array(add_kh) / totals * 100
percent_ki = np.array(add_ki) / totals * 100
percent_ap = np.array(add_ap) / totals * 100
percent_gen_all = np.array(add_all_gen) / totals * 100
percent_kh_all = np.array(add_all_kh) / totals * 100
percent_ki_all = np.array(add_all_ki) / totals * 100
percent_ap_all = np.array(add_all_ap) / totals * 100
rects1 = ax.bar(xyears - 1.5*width, percent_gen, width, label='Nur Generalistische Berufsbezeichnungen')
rects2 = ax.bar(xyears - 0.5*width, percent_kh, width, label='Nur Berufsbezeichnungen der Akutpflege')
rects3 = ax.bar(xyears + 0.5*width, percent_ki, width, label='Nur Berufsbezeichnungen der Kinderkrankenpflege')
rects4 = ax.bar(xyears + 1.5*width, percent_ap, width, label='Nur Berufsbezeichnungen der Altenpflege')
rects1_stack = ax.bar(xyears - 1.5*width, percent_gen_all, width, bottom=percent_gen, label='Generalistische Berufsbezeichnungen + Andere')
rects2_stack = ax.bar(xyears - 0.5*width, percent_kh_all, width, bottom=percent_kh, label='Berufsbezeichnungen der Akutpflege +  Andere')
rects3_stack = ax.bar(xyears + 0.5*width, percent_ki_all, width, bottom=percent_ki, label='Berufsbezeichnungen der Kinderkrankenpflege +  Andere')
rects4_stack = ax.bar(xyears + 1.5*width, percent_ap_all, width, bottom=percent_ap, label='Berufsbezeichnungen der Altenpflege +  Andere')
def add_bar_labels(rect_base, rect_stack):
    # Label for base bars (not stacked)
    for rect in rect_base:
        height = rect.get_height()
        ax.text(
            rect.get_x() + rect.get_width() / 2, 
            height - 0.5,  # Inside the base bar
            str(round(height, 2)),
            ha='center', va='top', color='black', fontsize=10, fontweight='bold'
        )

    # Label for stacked bars (positioned at the top of the stacked part, inside)
    for rect_b, rect_s in zip(rect_base, rect_stack):
        # Calculate the total height of the stacked bar (base + stacked)
        total_height = rect_b.get_height() + rect_s.get_height()
        ax.text(
            rect_s.get_x() + rect_s.get_width() / 2, 
            total_height - 2.5,  # Inside the stacked bar (just before top)
            str(round(rect_s.get_height(), 2)),  # Show only the value of the stacked part
            ha='center', va='bottom', color='black', fontsize=10, fontweight='bold'
        )

    # Label for total (base + stacked) bars, positioned outside the stacked bar
    for rect_b, rect_s in zip(rect_base, rect_stack):
        total_height = rect_b.get_height() + rect_s.get_height()
        ax.text(
            rect_s.get_x() + rect_s.get_width() / 2, 
            total_height + 0.5,  # Positioning the label outside the stacked bar (above)
            str(round(total_height, 2)),  # Show the total value
            ha='center', va='bottom', color='black', fontsize=10, fontweight='bold'
        )

add_bar_labels(rects1, rects1_stack)
add_bar_labels(rects2, rects2_stack)
add_bar_labels(rects3, rects3_stack)
add_bar_labels(rects4, rects4_stack)
ax.set_xlabel('Jahre')
ax.set_ylabel('Anzahl Stellenanzeigen in Prozent')
ax.set_title('Stellenanzeigen pro Jahr nach Art der Berufsbezeichnung (relativ)')
ax.set_xticks(xyears)
ax.set_xticklabels(years)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Genauere Betracht nur von den count_x_oza Werten --> diese sprechen die einzelne Gruppe x an, auch wenn andere
# Gruppen ebenfalls in der SteA genannt werden, so richtet sich diese doch auf jeden Fall an Gruppe X
#
# ToDo:
# Venn-Diagramme in relativ statt absolut!!!
#
# Kurve: SteA pro Jahr nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> absolut
# Kurve: SteA pro Jahr nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> relativ
# Bar: SteA pro Monat nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> absolut
# Bar: SteA pro Monat nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> releativ
# Kurve: SteA pro Monat nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> absolut
# Kurve: SteA pro Monat nach Gruppe (alle SteA pro Gruppe --> mit Überschneidungen zu anderen Gruppen) mit Kurve alle SteA --> relativ

#
# Bar + Kurve: SteA in jedem Jahr insgesamt --> absolut + relativ
# Bar + Kurve: SteA in jedem Monat (über alle Jahre) insgesamt --> absolut + relativ
# Bar + Kurve: Stea in jedem Jahr nach Gruppe --> absolut + relativ
# Bar + Kurve: SteA in jedem Monat (über alle Jahre hinweg) nach Gruppe --> absolut + relativ
# Torte: Alle SteA in allen Jahren Anteile der Gruppen
# Torte + Venn: Überschneidungen pro Jahr --> oben for-schleife einbauen!

# Hochschulisch qualifizierte rausfiltern und darstellen
